# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("Data/FullData.csv.gz")

# %%
len(df)
# Out:
# 7049

# %%
df.dropna(inplace=True)
df
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             66.033564          39.002274           30.227008
# 1             64.332936          34.970077           29.949277
# 2             65.057053          34.909642           30.903789
# 3             65.225739          37.261774           32.023096
# 4             66.725301          39.621261           32.244810
# ...                 ...                ...                 ...
# 2277          67.180378          35.816373           33.239956
# 2278          65.724490          36.301020           25.377551
# 2281          68.430866          38.651975           28.895857
# 2282          64.152180          30.691592           27.000898
# 2283          66.683755          34.483429           30.784490
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              36.421678                59.582075                39.647423
# ...

# %%
for series_name,series_data in df.items():
    if series_name!="Image":
        df[series_name]=df[series_name]/48-1
df
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0              0.375699          -0.187453           -0.370271
# 1              0.340270          -0.271457           -0.376057
# 2              0.355355          -0.272716           -0.356171
# 3              0.358870          -0.223713           -0.332852
# 4              0.390110          -0.174557           -0.328233
# ...                 ...                ...                 ...
# 2277           0.399591          -0.253826           -0.307501
# 2278           0.369260          -0.243729           -0.471301
# 2281           0.425643          -0.194751           -0.398003
# 2282           0.336504          -0.360592           -0.437481
# 2283           0.389245          -0.281595           -0.358656
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              -0.241215                 0.241293                -0.174012
# ...

# %%
df2=df.copy()
for series_name,series_data in df2.items():
    if series_name[len(series_name)-1]=="x":
        df2[series_name]=df2[series_name]*-1

# %%
Images=df2["Image"].copy()
imgs=Images.apply(lambda r:np.fromstring(r,sep=' ',dtype=int))
imgs=imgs.apply(lambda r:r.reshape(96,96))
imgs=imgs.apply(lambda r:r[:,::-1])
imgs=imgs.apply(lambda r:r.flatten())
imgs=imgs.apply(lambda r:[str(v) for v in r])
imgs=imgs.apply(lambda r:" ".join(r))
df2["Image"]=imgs
df2["Image"]
# Out:
# 0       250 250 250 251 248 250 252 242 188 133 128 11...
# 1       84 88 92 93 96 97 100 100 93 98 100 97 94 79 6...
# 2       207 207 208 207 207 208 213 205 175 176 156 10...
# 3       202 199 199 197 196 196 195 195 193 191 194 19...
# 4       213 192 151 119 111 94 86 68 75 80 69 71 71 62...
#                               ...
# 2277    21 21 18 19 33 34 48 60 61 70 89 99 99 100 102...
# 2278    9 7 3 5 10 15 17 19 23 23 19 11 7 5 6 5 4 5 5 ...
# 2281    197 198 198 197 195 191 184 155 71 43 33 37 38...
# 2282    38 20 9 9 40 20 34 41 27 30 18 13 5 6 5 4 5 7 ...
# 2283    3 8 3 2 21 22 19 4 6 3 2 2 5 11 11 11 16 10 15...
# Name: Image, Length: 2140, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 xy.iloc[:,:-1].values
#
# NameError: name 'xy' is not defined

# %%
toSwap=[(0,2),(1,3),(4,8),(5,9),(6,10),(7,11),(12,16),(13,17),(14,18),(15,19),(22,24),(23,25)]

# %%
## swap right left
for series_name in df2.columns.values:
    print(df2.columns.get_loc(series_name),series_name )
# Out:
# 0 left_eye_center_x
# 1 left_eye_center_y
# 2 right_eye_center_x
# 3 right_eye_center_y
# 4 left_eye_inner_corner_x
# 5 left_eye_inner_corner_y
# 6 left_eye_outer_corner_x
# 7 left_eye_outer_corner_y
# 8 right_eye_inner_corner_x
# 9 right_eye_inner_corner_y
# 10 right_eye_outer_corner_x
# 11 right_eye_outer_corner_y
# 12 left_eyebrow_inner_end_x
# 13 left_eyebrow_inner_end_y
# 14 left_eyebrow_outer_end_x
# 15 left_eyebrow_outer_end_y
# 16 right_eyebrow_inner_end_x
# 17 right_eyebrow_inner_end_y
# 18 right_eyebrow_outer_end_x
# 19 right_eyebrow_outer_end_y
# 20 nose_tip_x
# 21 nose_tip_y
# 22 mouth_left_corner_x
# 23 mouth_left_corner_y
# 24 mouth_right_corner_x
# 25 mouth_right_corner_y
# 26 mouth_center_top_lip_x
# 27 mouth_center_top_lip_y
# 28 mouth_center_bottom_lip_x
# 29 mouth_center_bottom_lip_y
# 30 Image

# %%
for pair in toSwap:
    tmp=df2.iloc[:,pair[0]].copy()
    df2.iloc[:,pair[0]]=df2.iloc[:,pair[1]].values
    df2.iloc[:,pair[1]]=tmp
df2
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0              0.370271          -0.241215           -0.375699
# 1              0.376057          -0.303152           -0.340270
# 2              0.356171          -0.272716           -0.355355
# 3              0.332852          -0.223713           -0.358870
# 4              0.328233          -0.207458           -0.390110
# ...                 ...                ...                 ...
# 2277           0.307501          -0.272460           -0.399591
# 2278           0.471301          -0.222683           -0.369260
# 2281           0.398003          -0.216312           -0.425643
# 2282           0.437481          -0.148582           -0.336504
# 2283           0.358656          -0.196272           -0.389245
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              -0.187453                 0.242571                -0.221054
# ...

# %%
Images=df["Image"]

fig = plt.figure(figsize=(15,15))
for j in range(1,10,2):
    img=np.fromstring(Images[j],dtype=int,sep=" ")
    img=img.reshape(96,96)
   
    ax=fig.add_subplot(3,3, j,xticks=[], yticks=[])
    for i in range(0,30,2):
        x,y=(df.iloc[j,i]+1)*48,(df.iloc[j,i+1]+1)*48
        c1=plt.Circle((x,y),2,color='r')
        ax.add_patch(c1)
    ax.imshow(img)

# %%
Images=df["Image"]
ImagesR=df2["Image"]
fig = plt.figure(figsize=(15,15))
for j in range(1,10,2):
    img=np.fromstring(Images[j],dtype=int,sep=" ")
    img=img.reshape(96,96)
    imgr=np.fromstring(ImagesR[j],sep=" ",dtype=int)
    imgr=imgr.reshape(96,96)
    ax=fig.add_subplot(6,2,j,xticks=[], yticks=[])
    ax2=fig.add_subplot(6,2, j+1, xticks=[], yticks=[])    
    for i in range(0,30,2):
        x,y=(df.iloc[j,i]+1)*48,(df.iloc[j,i+1]+1)*48
        xr,yr=(df2.iloc[j,i]+1)*48,(df2.iloc[j,i+1]+1)*48
        c=plt.Circle((xr,yr),2,color='r')
        c1=plt.Circle((x,y),2,color='r')
        ax.add_patch(c1)
        ax2.add_patch(c)
    ax2.imshow(imgr)
    ax.imshow(img)

# %%
idxCheck=0

# %%
Images=df["Image"]
ImagesR=df2["Image"]
fig = plt.figure(figsize=(15,15))
for j in range(1,10,2):
    img=np.fromstring(Images[j],dtype=int,sep=" ")
    img=img.reshape(96,96)
    imgr=np.fromstring(ImagesR[j],sep=" ",dtype=int)
    imgr=imgr.reshape(96,96)
    ax=fig.add_subplot(6,2,j,xticks=[], yticks=[])
    ax2=fig.add_subplot(6,2, j+1, xticks=[], yticks=[])    
    x,y=(df.iloc[j,idxCheck]+1)*48,(df.iloc[j,idxCheck+1]+1)*48
    xr,yr=(df2.iloc[j,idxCheck]+1)*48,(df2.iloc[j,idxCheck+1]+1)*48
    c=plt.Circle((xr,yr),2,color='r')
    c1=plt.Circle((x,y),2,color='r')
    ax.add_patch(c1)
    ax2.add_patch(c)
    ax2.imshow(imgr)
    ax.imshow(img)

# %%
df2
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             -0.375699          -0.187453            0.370271
# 1             -0.340270          -0.271457            0.376057
# 2             -0.355355          -0.272716            0.356171
# 3             -0.358870          -0.223713            0.332852
# 4             -0.390110          -0.174557            0.328233
# ...                 ...                ...                 ...
# 2277          -0.399591          -0.253826            0.307501
# 2278          -0.369260          -0.243729            0.471301
# 2281          -0.425643          -0.194751            0.398003
# 2282          -0.336504          -0.360592            0.437481
# 2283          -0.389245          -0.281595            0.358656
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              -0.241215                -0.241293                -0.174012
# ...

# %%
Merged=pd.concat([df,df2],ignore_index=True)

# %%
Merged.to_csv("Data/EditedData.csv.gz",index=False,compression='gzip')

# %%
OpenTest=pd.read_csv("Data/EditedData.csv.gz")

# %%
OpenTest
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0              0.375699          -0.187453           -0.370271
# 1              0.340270          -0.271457           -0.376057
# 2              0.355355          -0.272716           -0.356171
# 3              0.358870          -0.223713           -0.332852
# 4              0.390110          -0.174557           -0.328233
# ...                 ...                ...                 ...
# 4275           0.307501          -0.272460           -0.399591
# 4276           0.471301          -0.222683           -0.369260
# 4277           0.398003          -0.216312           -0.425643
# 4278           0.437481          -0.148582           -0.336504
# 4279           0.358656          -0.196272           -0.389245
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              -0.241215                 0.241293                -0.174012
# ...

# %%
Images=OpenTest["Image"]
fig = plt.figure(figsize=(15,15))
for j in range(1,10,2):
    img=np.fromstring(Images[j+10],dtype=int,sep=" ")
    img=img.reshape(96,96)
    imgr=np.fromstring(Images[j+2140+10],sep=" ",dtype=int)
    imgr=imgr.reshape(96,96)
    ax=fig.add_subplot(6,2,j,xticks=[], yticks=[])
    ax2=fig.add_subplot(6,2, j+1, xticks=[], yticks=[])    
    for i in range(0,30,2):
        x,y=(OpenTest.iloc[j+10,i]+1)*48,(OpenTest.iloc[j+10,i+1]+1)*48
        xr,yr=(OpenTest.iloc[j+10+2140,i]+1)*48,(OpenTest.iloc[j+10+2140,i+1]+1)*48
        c=plt.Circle((xr,yr),2,color='r')
        c1=plt.Circle((x,y),2,color='r')
        ax.add_patch(c1)
        ax2.add_patch(c)
    ax2.imshow(imgr)
    ax.imshow(img)
